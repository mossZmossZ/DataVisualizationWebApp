# %%
import altair as alt
import altair_viewer
import pandas as pd
from ChartManager import ChartManager

alt.data_transformers.disable_max_rows()
# altair_viewer._global_viewer._use_bundled_js = False
# alt.data_transformers.enable('data_server')
# alt.data_transformers.enable('json')

# alt.data_transformers.enable('json', urlpath='files')

df = pd.read_csv("test/covid19data/total_casesanddeath_by_provinces.csv")
# df.drop(index=df[df["province"].isin(["All","None"])].index, inplace=True)
# Out:
#         province                 region  year  weeknum  new_case  total_case  \
# 0         Ranong                 ภาคใต้  2023       10         1           2
# 1     Nonthaburi                ภาคกลาง  2023       10         2         126
# 2       Lop Buri                ภาคกลาง  2023       10         2          49
# 3     Chiang Mai               ภาคเหนือ  2023       10         0          18
# 4       Yasothon  ภาคตะวันออกเฉียงเหนือ  2023       10         0          20
# ...          ...                    ...   ...      ...       ...         ...
# 4182  Chiang Mai               ภาคเหนือ  2022       52         3       36805
# 4183    Lop Buri                ภาคกลาง  2022       52        14       16403
# 4184    Yasothon  ภาคตะวันออกเฉียงเหนือ  2022       52         6       14114
# 4185  Nonthaburi                ภาคกลาง  2022       52        84       75682
# 4186      Ranong                 ภาคใต้  2022       52         1       10814
#
#       new_death  total_death
# 0             0            0
# 1             0            2
# 2             0            1
# 3             0            8
# 4             0            3
# ...         ...          ...
# 4182          2          327
# 4183          0          225
# 4184          0          106
# 4185          1          114
# 4186          0           26
#
# [4187 rows x 8 columns]

# %%
obj = ChartManager()
obj.setDataframe(df)
obj.ThailandTopoChart(500,600)
# Out:
# alt.Chart(...)

# %%
#if get only one region
# obj.setDataframe(df.loc[df['region'] == "ภาคตะวันออก"])
#นี่เป็นตัวอย่างการ query ให้ดูว่า chart จะมีลักษณะเป็นอย่างไร
#แต่ถ้าของจริงจะต้องใช้ไฟล์ที่ query มาจาก Back-end แล้วนำไฟล์นั้นไปใช้เลย
# obj.ThailandTopoChart(300,400)

# %%
# obj.setDataframe(df.loc[(df['region'] == "ภาคเหนือ")|(df['region'] == "ภาคกลาง")])
# obj.ThailandTopoChart(300,400)

# %%
# obj = ChartManager()
# obj.setDataframe(df)
obj.BarChart()
# Out:
# alt.FacetChart(...)

# %%
obj.LineChart()
# Out:
# alt.RepeatChart(...)
